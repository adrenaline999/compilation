# %% [markdown]
# <a href="https://colab.research.google.com/github/adrenaline999/compilation/blob/main/%20lab2_titanic_Visilino.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. What are your steps in cleaning the dataset? Why did you choose the algorithm that you used in cleaning the dataset?
# Answer: To clean the dataset, I first loaded it using Pandas and checked for missing values. The Age column had null values, which I filled with the median age since it's less sensitive to outliers, while the Embarked column was filled with its mode as it had only two missing values. The Cabin column was dropped due to excessive missing data. Next, I converted categorical variables like Sex and Embarked into numerical values for easier analysis and visualization. I also removed duplicate entries to maintain data integrity. After cleaning, I performed two basic analyses. First, I examined the survival rate by gender, which revealed that females had a significantly higher survival rate than males, supporting the "women and children first" evacuation rule. Second, I analyzed the age distribution, showing that most passengers were in their 20s and 30s, with a noticeable spike in younger passengers, suggesting that many families with children were on board. These insights highlight key survival patterns and demographic trends among Titanic passengers.

# %% [markdown]
# 2. Create at least two (2) basic data analysis on two (2) columns in the dataset. Be creative and critical in deriving the insights on the data. You can show the visualization used to derive the insights.
# Answer: ![Screenshot_17-3-2025_02652_jupyter.org.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_17-3-2025_02721_jupyter.org.jpeg](data:image/jpeg;base64,...)
